# %%
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/py/lib/python3.6/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      84             else:
# ---> 85                 return self.cursor.execute(sql, params)
#      86
#
# ~/py/lib/python3.6/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     302         query = self.convert_query(query)
# --> 303         return Database.Cursor.execute(self, query, params)
#     304
#
# IntegrityError: ankieter_pytanie.pub_date may not be NULL
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-10-5086967d422f> in <module>()
# ----> 1 p = Pytanie.objects.create()
#
# ...
